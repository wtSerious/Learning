# %% [markdown]
# emmmmmmmmmmm...............
# 原本是想写logistic回归，写着写着。。就写歪了。。。。写成了线性回归。。。
# 这相当于是第一篇博客，所以想着把很多东西都纳入进去，也方便自己回顾一些基础内容。、
# 写博客还是很耗时间的。。感觉自己想写的东西还远远没完，时间来不及，作业交了再说！

# %% [markdown]
# ### 什么是回归
# 目前我把它理解为：已知有输入 {$x_{1},x_{2},...,x_{n}$} 和线性函数 $f(x)$。根据函数 $f(x)$ 和输入 $X$ 可以得到输出 {$y_{1},y_{2},...,y_{n}$}。以上过程是已知输入和函数来得到相应的输出，现在我们的目标是通过输入 $X$ 和输出 $Y$ 来寻找和拟合 $f(x)$ 函数。

# %% [markdown]
# ### 定义 $f(x)$
# 通常一个线性函数 $f(x)$ 可以写成 $f(x)$ = $a + bx + cx^{2} + dx^{3}+..$ 把它写成矩阵的形式就是 $f(x)$ = $WX + b$
# 从这个式子可知，一个线性函数由 $W$ 和 $b$ 这两个参数决定，不同的 $W$ 和不同的 $b$ 都会产生不同的线性函数。显然我们只要找到正确 $W$ 和 $b$ 就是找到了正确的 $f(x)$。

# %% [markdown]
# ### 判断是否找到了正确的 $f(x)$
# 首先，我们不应该急于思考怎么找 $f(x)$ 而是先解决如何判断一个我们千方百计的找到的$f^{'}(x)$,就是正确的 $f(x)$ 的问题。
# 一个很显然的想法就是通过判断 输入 X 通过 $f^{‘}(x)$ 是否产生了与真实输出 $Y$ 一样的输出。于是把 $Y^{'}$ 与真实输出 $Y$ 的差异作为衡量 $f^{'}(x)$ 拟合 $f(x)$ 程度的标准。然后就是怎么量化两个数据间的差异，然后就出现了一个很常用的函数————均方误差，$\tfrac{1}{n}$$\sum_{n}(y_{i}-f(x_{i})^{'})^{2}$,这就是损失函数。

# %% [markdown]
# ### 如何找正确的 $f(x)$
# 已知损失函数 $loss(w,b)$ $ = \tfrac{1}{n}$$\sum_{n}(y_{i}-
# f(x_{i})^{'})^{2}$,$w$ 和 $b$ 是损失函数的参数，也是我们需要优化的参数。可以发现损失函数越小说明 $f^{'}(x)$ 越接近正确的 $f(x)$，那么我们的目标就是使损失函数最小，于是就出现了梯度下降方法。
#
# 在学习高数时，对一维函数 $g(x)$ 进行求导时，就是在 $y = g(x)$ 处画了条切线，切线的斜率就是导数，导数的正负表示这个 $g(x)$ 在点 $x$ 处是在增大还是减小。如果导数是正，我们只要减小 $x$ 就能减小 $y = g(x)$，反之，增大 $x$。总而言之，$x$的移动反向总是与梯度方向相反, $x^{new} = x^{old} - \tfrac{\Delta g(x))}{\Delta x^{old}}$,这就是梯度下降法，每次都通过移动 $x$ 达到函数下降，经过多次的迭代后可以达到一个好的效果。
#
# 现在回到对损失函数的讨论,在参数空间中任意的取一组参数 $(w^{'},b^{'})$,当然我们没有这个运气直接取到正确的 $(w,b)$，通常都会得到较坏的结果。然后把损失函数 $loss(w^{'},b^{'})$ 对 $w$ 和 $b$求偏导于是得到损失函数在(w^{'},b^{b})下对 $w$ 和 $b$ 两个方向的增减情况，现在我们的参数的二维的，于是我们能得到一个切平面,如果 $W$ 的维度不是一而是更高的，那么就是一个超平面。运用梯度下降思想，使 $w$ 每次都向使损失函数下降移动的方向 $w^{new} = w^{'} - \frac{\Delta loss(w,b))}{\Delta w^{'}}$,同理得到$b^{new} = b^{'} - \frac{\Delta loss(w,b))}{\Delta b^{'}}$。

# %% [markdown]
# ### 往下降方向移动多少
# 现在我们已经有了一个似乎很好的方法来下降损失函数，下面考虑一个情况:
# ![%E6%97%A0%E6%A0%87%E9%A2%98.png](attachment:%E6%97%A0%E6%A0%87%E9%A2%98.png)

# %% [markdown]
# $x^{'}$ 是初始点，如果 $x$ 的移动距离只依赖于梯度的大小，$x^{'}$ 很可能就只移动到 $x_{1}$ ，$x_{1}$ 的梯度比 $x^{'}$ 的梯度小，移动的距离会更小，就算继续进行梯度下降，也无法到达最小值点 $x_{'}$，只能到达局部极小值点，梯度为0，损失不再减小。为了解决这个问题，不妨人为的设计一个参数来控制移动距离的大小，这就是学习率 $\eta$，用它来放大或缩小移动距离。于是梯度更新变成了 $x^{new} = x^{old} - \eta  \frac{\Delta g^{'}(x))}{\Delta x^{old}}$。
# 引入学习率 $\eta$ 后，又会产生一个问题， $\eta$ 应该多大，如果 $\eta$ 过大会导致 ${x^{'}}$ 移动到 ${x_{3}}$，然后 ${x_{3}}$ 又会移动到${x^{'}}$那边去，就这样两边旋转跳跃~所以设计如何设计一个好的学习率也是一个很重要的问题。

# %% [markdown]
# 其实在这里还有对梯度下降和局部极小值点和鞍点的讨论，但是手贱删掉了，悲剧......

# %% [markdown]
# ### 从回归到分类
# >有一种思想是将分类问题作为回归问题来处理，我们以二分类(Binary Classfication)为例，即输出只有两种类别，在训练时类别一的标签用 1 表示，类别二用 -1 表示。而在测试时，回归问题的测试数据不会正好是 1 或是 -1，因此预测值越接近 1 则分类为类别一，否则分类为类别二。所以可以将 0 作为分界线，预测值大于 0 时认为它接近于 1，小于 0 时认为它接近于 -1.

# %% [markdown]
# ![binary-classification-re.png](attachment:binary-classification-re.png)

# %% [markdown]
# >这种思想存在一种缺陷，假设现在的线性模型为 $y = w_{1}x_{1} + w_{2}x_{2}$，即输入的特征为 $x_{1}$ 和 $x_{2}$，上图中蓝色的点为类别一，红色的点为类别二，经过训练后得到的函数 (两个类别的分界) 使用图中的直线 $b + w_{1}x_{1} + w_{2}x_{2} = 0$ 来表示。但如果类别一的数据分布如右图所示时，假设使用绿色线，右下角的那些点的输出可能远远大于 1，这对于回归模型来说是不好的样本点，会造成很大的训练误差，因为我们定义损失函数为均方差，右下角的数据的输出可能会比1大，甚至大很多，说明右下角十分属于类别一，损失却非常大。因此实际在训练后，得到的最好的函数可能是紫色线条，这样右下角的蓝色点造成的误差会小一些。

# %% [markdown]
# >那么我们如何解决这个缺陷呢:
# - 找一个函数 $f(x)$，其输出不应该像回归模型一样的连续，而应该是离散型数值。
# - 重新定义损失函数，把损失定义为当前函数 $f$ 在训练数据上预测的错误次数或错误率，即 $L(f) = \sum_{n}\delta (f(x^{n})!=y^{n})$,其中 $\delta$ 在预测错误时取 1,预测正确时取 0。
# - 重新定义损失函数又会产生一个问题，新的损失函数是一个离散型的函数，所以无法对它用梯度下降法进行优化。所以损失函数也不能使分类的错误次数和错误率，在感知机或 SVM 都选择了数据点到超平面的距离作为损失函数。

# %% [markdown]
# ### 线性分类：概率生成模型
# 假设现在有 150 个数据 $(x_{1},x_{2},...,x_{150})$ ,它们可以被划分为两类: $(C_{1}，C_{2})

# %% [markdown]
# 有 79 个为 $C_{1}$ 类，71 个为 $C_{2}$ 类。当我们判断一个数据 $x$ 属于哪一类时，可以通过计算 $P(C_{1}$ | $x)$ 和 $P(C_{1}$ | $x)$ ，比较两者的大小，哪个的概率大就属于哪一类。
# $$P(C_{1} | x) = \frac{P(C_{1}, x )}{P(x)}$ = $\frac{P(x | C_{1}) P(C_{1})}{P(C_{1},x) + P(C_{2},x)}$ =
# $\frac{P(x | C_{1}) P(C_{1})}{P(x | C_{1})P(C_{1}) + P(x|C{2})P(C_{2})}$$
# 已知 $P(C_{1})$ 和 $P(C_{2})$ 的值分别为: $\frac{79}{150}$ 和 $\frac{71}{150}$，如果能知道 $P(x | C_{1})$ 和 $ P(x|C{2})$ 的值，就能求出 $P(C_{1} | x)$。
#
# $P(x | C_{1})$ 表示 $C_{1}$ 类产生 $x$ 的概率。假设 $C_{1}$ 类表示的是一个高斯分布，$P(x | C_{1})$ 指高斯分布 $C_{1}$ 抽样出 $x$ 的概率。如果 $x$ 由特征 $(u_{1},u_{2},u_{3})$ 构成， 则设 $C_{1}$ 高斯分布为:
# $$f(u,\sum,x) = \frac{1}{\sqrt{2 \pi}^{n}} \frac{1}{\sqrt{|\sum|}} exp(- \frac{1}{2}(x-u)^{T} \sum ^{-1} (x-u))$$
# 其中 $\sum$ 表示协方差矩阵，$u$ 表示高斯函数的期望，高斯函数由 $\sum$ 和 $u$ 决定。79 个属于 $C_{1}$ 类的数据点正是由这个高斯函数产生，好了，现在又回到那个问题了，根据输入和输出来求高斯函数。

# %% [markdown]
# ### 最大似然
# 现在又变成了学习问题啦，我们应该对这种概率分布问题定义一个什么损失函数好呢？它就是似然函数。
# >首先我们要知道任何的高斯分布，都有可能抽样出这 79 个点，因为高斯分布可以抽样出空间中的任意一点，只是有些点被抽样出来的概率会非常低，但又不会达到0。

# %% [markdown]
# 但是不同的高斯分布产生这 79 个点的难易程度肯定是不同的，我们相信容易抽样出这个 79 个点的高斯分布更符合真实的高斯分布。接着我们整体考虑 79 个样本，计算某高斯分布产生这 79 个点的概率:
# $$L(u,\sum) = f(u,\sum,x_{1}) f(u,\sum,x_{2}) f(u,\sum,x_{3})...f(u,\sum,x_{4})$$
# >$L(u,\sum)$ 就是似然函数，不是损失。因为所有 79 个点是独立被抽样出来的，所以"高斯分布抽样出这 79 个点"这个时间的概率为分别单词抽样出这 79 个点的概率之积。

# %% [markdown]
# 接下来我们的目标就是在参数空间寻找最佳的 $u$ 和 $\sum$，使似然达到最大，能使似然达到最大的高斯分布我们认为它就是最接近真实分布的最佳高斯分布，于是问题变成了 $arg max_{u,\sum} L(u,\sum)$。

# %% [markdown]
# >可以通过微积分取求解，或者记住结果:$$u^{*} = \frac{1}{79} \sum^{79}_{n=1}x_{n}$$
# $$\sum^{*} = \frac{1}{79}\sum^{79}_{n=1}(x^{n}-u^{*})(x^{n}-u^{*})^{T}$$
# 通过极大似然估计出某个类 $C$ 的高斯分布 $(u^{*},\sum^{*})$,就能够估计某个 $x$ 从中被抽样出来的概率
# $$P(x|C_{1}) = f(u^{*},\sum^{*},x) = \frac{1}{\sqrt{2 \pi}^{n}} \frac{1}{\sqrt{|\sum^{*}|}} exp(- \frac{1}{2}(x-u^{*})^{T} \sum ^{-1} (x-u^{*}))$$

# %% [markdown]
# ### Sigmoid函数
# >$$P(C_{1}|x) = \frac{P(x|C_{1})P(C_{2})}{P(x|C_{1})P(C_{1}) + P(x|C_{2})P(C_{2})} = \frac{1}{1 +\frac{P(x|C_{2})P(C_{2})}{P(x|C_{1})P(C_{1})}}$$
# >设 $z = ln\frac{P(x|C_{1})P(C_{1})}{P(x|C_{2})P(C_{2})}$
# 则$P(C_{1}|x) = \frac{1}{1 +exp(-z)} = \sigma(-z)$
# >我们注意到最终形式函数 $\sigma(z)$ 输入为z，这个函数叫作 sigmoid 函数。接下来计算一下z:
# >$$z = ln\frac{P(x|C_{1})P(C_{1})}{P(x|C_{2})P(C_{2})} = ln\frac{P(x|C_{1})}{P(x|C_{2})} + ln\frac{P(C_{1})}{P(x|C_{2})} $$
# $z$ 的右边项很容易就能计算出 $ln\frac{P(C_{1})}{P(C_{2})} = \frac{N_{1}}{N_{2}} ,计算 $z$ 的左边项:
# >$$ln\frac{P(x|C_{1})}{P(x|C_{2})} = ln \frac{
# P(x|C_{1}) = f(u^{1},\sum^{1},x) = \frac{1}{\sqrt{2 \pi}^{n}} \frac{1}{\sqrt{|\sum^{1}|}} exp(- \frac{1}{2}(x-u^{1})^{T} (\sum^{1})^{-1} (x-u^{1}))}{
# P(x|C_{1}) = f(u^{1},\sum^{1},x) = \frac{1}{\sqrt{2 \pi}^{n}} \frac{1}{ \sqrt{| \sum^{2} |}} exp(- \frac{1}{2}(x-u^{2})^{T} (\sum^{2}) ^{-1} (x-u^{2}))} = ln \frac{\sqrt{|\sum^{1}|}}{\sqrt{|\sum^{2}|}} exp(-\frac{1}{2}( (x-u^{1})^{T} (\sum^{1})^{-1} (x-u^{1})-(x-u^{2})^{T} (\sum^{2})^{-1} (x-u^{2})))$$

# %% [markdown]
# >分别展开其中的项：
# $$(x-u^{1})^{T} (\sum^{1})^{-1} (x-u^{1}) =$$ $$x^{T}(\sum^{1})^{-1}x - x^{T}(\sum^{1})^{-1}u^{1} - (u^{1})^{T}(\sum^{1})^{-1}x + (u^{1})^{T}(\sum^{1})^{-1}u^{1} $$
#
# $$(x-u^{2})^{T} (\sum^{2})^{-1} (x-u^{2}) =$$ $$ x^{T}(\sum^{2})^{-1}x - x^{T}(\sum^{2})^{-1}u^{2} - (u^{2})^{T}(\sum^{2})^{-1}x + (u^{2})^{T}(\sum^{2})^{-1}u^{2} $$

# %% [markdown]
# >因此可以计算出 $z$: = $ln\frac{|\sum^{2}|^1/2}{|\sum^{2}|^{1/2}} - \frac{1}{2}x^{T}(\sum^{1})^{-1}x + (u^{1})^{T}(\sum^{1})^{-1}x - \frac{1}{2}(u^{1})^{T}(\sum^{1})^{-1}u^{1} + \frac{1}{2}x^{T}(\sum^{2})^{-1}x - (u^{2})^{T}(\sum^{2})^{-1}x - \frac{1}{2}(u^{2})^{T}(\sum^{2})^{-1}u^{2} + ln\frac{N_{1}}{N_{2}}$

# %% [markdown]
# >现在我们已经假设协方差矩阵共用，则有 $\sum^{1} = \sum^{2} = \sum$ ，于是z: $$z = (u^{1} - u^{2})^{T}\sum^{-1} - \frac{1}{2}(u^{1})^{T}(\sum^{1})^{-1}u^{1}+ (u^{2})^{T}(\sum^{2})^{-1}u^{2} + ln\frac{N_{1}}{N_{2}}$$

# %% [markdown]
# >可以发现上式只有一项含有 x,发现$\frac{1}{2}(u^{1})^{T}(\sum^{1})^{-1}u^{1}$ 和 $(u^{2})^{T}(\sum^{2})^{-1}u^{2}$其实是标量，因此可以简写为 $$z = W^{T}x + b$$ $$P(C_{1}|x) = \sigma(W^{T}x + b)$$

# %% [markdown]
# ### 逻辑斯蒂回归
# 从上面我们已经知道 $P(C_{1}|x) =\frac{P(x|C_{1})P(C_{1})}{P(x|C_{1})P(C_{1})+P(x|C_{2})P(C_{2})} = \sigma(z) = \frac{1}{1+exp(-z)} $
# 可以发现通过 sigmoid 函数把我们的输出转换为概率。下面来谈谈逻辑斯蒂回归的学习过程：
#
# 损失函数是似然函数 $L(w,b) = y_{1}P(C_{1}|x) + y_{2}P(C_{2}|x) (y_{1} + y+{2} = 1)$，优化方法当然是随机梯度下降法.
# $$\frac{\delta L(w,b)}{\delta w} = y_{1}(z(1-z))x + y_{2}(z(1-z))x = y_{1}(z(1-z))x + (1-y_{1})(z(1-z))x = z(1-z)   (其中z = W^{T}x + b)$$
